# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\nagal/Downloads/TCS.NS.csv",parse_dates=True,index_col="Date")

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2469 entries, 2013-02-22 to 2023-02-22
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2467 non-null   float64
#  1   High       2467 non-null   float64
#  2   Low        2467 non-null   float64
#  3   Close      2467 non-null   float64
#  4   Adj Close  2467 non-null   float64
#  5   Volume     2467 non-null   float64
# dtypes: float64(6)
# memory usage: 135.0 KB

# %%
data.shape
# Out:
# (2469, 6)

# %%
data.isnull().sum()
# Out:
# Open         2
# High         2
# Low          2
# Close        2
# Adj Close    2
# Volume       2
# dtype: int64

# %%
data=data.dropna()
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
data.shape
# Out:
# (2467, 6)

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2467.000000  2467.000000  2467.000000  2467.000000  2467.000000
# mean   1909.302876  1928.600574  1888.589800  1908.491528  1760.051270
# std     893.060879   900.275859   884.426285   892.367872   917.257829
# min     682.500000   691.000000   682.500000   684.674988   554.956970
# 25%    1223.000000  1234.674988  1211.924988  1221.975036  1057.432861
# 50%    1477.000000  1499.800049  1463.275024  1479.650024  1327.199585
# 75%    2291.224976  2333.900024  2273.925049  2297.425049  2187.835327
# max    4033.949951  4043.000000  3980.000000  4019.149902  3885.789795
#
#              Volume
# count  2.467000e+03
# mean   2.724261e+06
# std    2.383317e+06
# min    0.000000e+00
# 25%    1.682374e+06
# 50%    2.290762e+06
# 75%    3.166122e+06
# max    8.806715e+07

# %%
data.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999761  0.999760  0.999501   0.998954  0.030198
# High       0.999761  1.000000  0.999733  0.999804   0.999274  0.035182
# Low        0.999760  0.999733  1.000000  0.999791   0.999240  0.026448
# Close      0.999501  0.999804  0.999791  1.000000   0.999447  0.030542
# Adj Close  0.998954  0.999274  0.999240  0.999447   1.000000  0.030518
# Volume     0.030198  0.035182  0.026448  0.030542   0.030518  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.displot(data.Close)

# %%
data.hist(figsize=(12,6))
# Out:
# array([[<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'High'}>],
#        [<AxesSubplot:title={'center':'Low'}>,
#         <AxesSubplot:title={'center':'Close'}>],
#        [<AxesSubplot:title={'center':'Adj Close'}>,
#         <AxesSubplot:title={'center':'Volume'}>]], dtype=object)

# %% [markdown]
# # Moving average

# %%
MA100=data['Close'].rolling(50).mean()
MA100.plot().grid()

# %%
MA200=data['Close'].rolling(200).mean()
MA200.plot().grid()

# %%
data.plot(subplots=True, figsize=(10, 12))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %% [markdown]
# ## Resampling

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
data.resample(rule='M').mean()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-28   735.150000   746.705005   732.235010   742.539990   601.858777
# 2013-03-31   775.306580   783.261844   769.782895   777.755256   630.402206
# 2013-04-30   741.006250   747.364996   729.218744   736.816254   597.219476
# 2013-05-31   735.481814   745.450001   729.620453   738.813635   598.838446
# 2013-06-30   729.178751   738.731250   719.502499   729.618750   595.873004
# ...                 ...          ...          ...          ...          ...
# 2022-10-31  3114.671040  3140.342092  3089.400018  3118.149979  3052.547530
# 2022-11-30  3299.314290  3326.635719  3274.702381  3308.226179  3242.543062
# 2022-12-31  3308.375022  3333.245461  3280.170455  3308.034102  3242.354781
# 2023-01-31  3344.342855  3373.397624  3314.107155  3351.288098  3320.037074
# 2023-02-28  3484.649979  3511.228119  3461.131241  3486.515640  3486.515640
#
#                   Volume
# Date
# ...

# %%
data.resample(rule='M').Close.mean().plot(kind='line',figsize=(25,12)).grid()

# %%
#QS Quarterly info
data.resample(rule='QS').min()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-01-01   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-04-01   682.500000   691.000000   682.500000   684.674988   554.956970
# 2013-07-01   745.424988   754.250000   732.500000   744.900024   609.166931
# 2013-10-01   966.000000   977.424988   958.349976   974.525024   798.750977
# 2014-01-01  1019.000000  1037.500000  1005.700012  1019.700012   838.937866
# 2014-04-01  1014.000000  1044.500000   999.750000  1018.349976   837.827026
# 2014-07-01  1185.500000  1205.000000  1167.500000  1175.900024   976.732056
# 2014-10-01  1175.000000  1192.500000  1172.500000  1179.324951   996.859070
# 2015-01-01  1221.199951  1224.500000  1203.724976  1208.849976  1021.816223
# 2015-04-01  1214.400024  1226.000000  1200.500000  1213.525024  1027.820679
# 2015-07-01  1237.699951  1252.500000  1227.500000  1237.175049  1057.592773
# ...

# %%
data.resample(rule='QS').Close.min().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.resample(rule='QS').Open.mean().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# for yearly data
data.resample(rule='Y').mean()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-12-31   874.969286   886.888689   865.373928   876.127143   715.972175
# 2014-12-31  1186.401024  1199.089852  1172.604614  1185.523564   988.203347
# 2015-12-31  1270.948879  1281.719204  1257.073786  1268.712906  1082.479572
# 2016-12-31  1209.537294  1221.234447  1196.120125  1209.673986  1053.469579
# 2017-12-31  1237.662195  1249.830942  1226.309277  1237.889216  1098.717083
# 2018-12-31  1785.393189  1804.510975  1766.011488  1785.442680  1612.908231
# 2019-12-31  2103.345265  2123.375097  2078.124697  2101.215439  1932.539650
# 2020-12-31  2264.134659  2295.067719  2234.434472  2263.177490  2149.704058
# 2021-12-31  3355.152823  3387.482462  3322.478835  3353.852824  3228.449283
# 2022-12-31  3400.016331  3428.547977  3364.843961  3397.281645  3308.575211
# 2023-12-31  3405.016206  3433.000000  3377.685138  3409.764873  3392.027806
#
#                   Volume
# Date
# ...

# %%
data.resample(rule='Y').Open.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.resample(rule='Y').Close.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data[['Open','Close']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.boxplot(data.Close)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f651629be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f6516371c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f651629910>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f651637760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f651637a30>],
#  'means': []}

# %% [markdown]
# ## Stationarity Test

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
plt.xlabel('Date')
plt.ylabel('Closing Price')
data.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Closing Price'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add = seasonal_decompose(data.Close,period=12)
decompose_ts_add.plot()
plt.show()

# %%
rolmean12=data.rolling(window=12).Close.mean().plot()
rolmean20=data.rolling(window=20).Close.mean().plot()

# %%
rolvar12=data.rolling(window=12).Close.var().plot()
rolvar20=data.rolling(window=20).Close.var().plot()

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
adf_test(data.Close)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.547934
# p-value                           0.882318
# #Lags Used                        5.000000
# Number of Observations Used    2461.000000
# Critical Value (1%)              -3.433010
# Critical Value (5%)              -2.862715
# Critical Value (10%)             -2.567396
# dtype: float64

# %%
log_data = data['Close'].apply(lambda x : np.log(x))

ax1 = plt.subplot(121)
log_data.plot(figsize=(12,4) ,color="tab:red", title="Log Transformed Values", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(color="tab:red", title="Original Values", ax=ax2);

# %%
decompose_ts_add = seasonal_decompose(log_data,period=12)
decompose_ts_add.plot()
plt.show()

# %%
power_data = data["Close"].apply(lambda x : x ** 0.5)

ax1 = plt.subplot(121)
power_data.plot(figsize=(12,4), color="tab:red", title="Powered Transformed Values", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
decompose_ts_add = seasonal_decompose(power_data,period=24)
decompose_ts_add.plot()
plt.show()

# %%
rolling_mean = data.Close.rolling(window = 12).mean()
data_rolled_detrended = data.Close - rolling_mean

ax1 = plt.subplot(121)
data_rolled_detrended.plot(figsize=(12,4),color="tab:red", title="Differenced With Rolling Mean over 12 month", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
data_rolled_detrended=data_rolled_detrended.dropna()
data_rolled_detrended
# Out:
# Date
# 2013-03-11    21.389567
# 2013-03-12    14.147924
# 2013-03-13     6.497900
# 2013-03-14    11.527069
# 2013-03-15     9.175008
#                 ...
# 2023-02-16    62.779195
# 2023-02-17    -1.854269
# 2023-02-20   -17.945801
# 2023-02-21   -51.637512
# 2023-02-22   -96.220805
# Name: Close, Length: 2456, dtype: float64

# %%
decompose_ts_add = seasonal_decompose(data_rolled_detrended.dropna(),period=12)
decompose_ts_add.plot()
plt.show()

# %%
logged_data = pd.DataFrame(data["Close"].apply(lambda x : np.log(x)))

rolling_mean = logged_data.rolling(window = 12).mean()
data_log_rolled_detrended = logged_data["Close"] - rolling_mean["Close"]


ax1 = plt.subplot(121)
data_log_rolled_detrended.plot(figsize=(12,4),color="tab:red", title="Log Transformation & Differenced With Rolling Mean over 12 month", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
decompose_ts_add = seasonal_decompose(data_log_rolled_detrended.dropna(),period=12)
decompose_ts_add.plot()
plt.show()

# %%
powered_data = pd.DataFrame(data["Close"].apply(lambda x : x ** 0.5))

rolling_mean = powered_data.rolling(window = 12).mean()
data_pow_rolled_detrended = powered_data["Close"] - rolling_mean["Close"]


ax1 = plt.subplot(121)
data_pow_rolled_detrended.plot(figsize=(12,4),color="tab:red", title="Power Transformation & Differenced With Rolling Mean over 12 month", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
decompose_ts_add = seasonal_decompose(data_pow_rolled_detrended.dropna(),period=12)
decompose_ts_add.plot()
plt.show()

# %%
from statsmodels.regression.linear_model import OLS

least_squares = OLS(data["Close"].values, list(range(data.shape[0])))
result = least_squares.fit()

fit = pd.Series(result.predict(list(range(data.shape[0]))), index = data.index)

data_ols_detrended = data["Close"] - fit


ax1 = plt.subplot(121)
data_ols_detrended.plot(figsize=(12,4), color="tab:red", title="Linear Regression Fit", ax=ax1);
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
decompose_ts_add = seasonal_decompose(data_ols_detrended,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# # Seasonality

# %%
logged_data_diff = log_data- log_data.shift()

ax1 = plt.subplot(121)
logged_data_diff.plot(figsize=(12,4), color="tab:red", title="Log-Transformed & Differenced Time-Series", ax=ax1)
ax2 = plt.subplot(122)
data.Close.plot(figsize=(12,4), color="tab:red", title="Original Values", ax=ax2);

# %%
logged_data_diff
# Out:
# Date
# 2013-02-22         NaN
# 2013-02-25    0.012702
# 2013-02-26    0.015286
# 2013-02-27   -0.008860
# 2013-02-28    0.022533
#                 ...
# 2023-02-16    0.010567
# 2023-02-17   -0.016121
# 2023-02-20   -0.003964
# 2023-02-21   -0.010464
# 2023-02-22   -0.014433
# Name: Close, Length: 2467, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
adf_test(logged_data_diff.dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -21.986768
# p-value                           0.000000
# #Lags Used                        4.000000
# Number of Observations Used    2461.000000
# Critical Value (1%)              -3.433010
# Critical Value (5%)              -2.862715
# Critical Value (10%)             -2.567396
# dtype: float64

# %%
log_data=pd.DataFrame(logged_data_diff)
log_data
# Out:
#                Close
# Date
# 2013-02-22       NaN
# 2013-02-25  0.012702
# 2013-02-26  0.015286
# 2013-02-27 -0.008860
# 2013-02-28  0.022533
# ...              ...
# 2023-02-16  0.010567
# 2023-02-17 -0.016121
# 2023-02-20 -0.003964
# 2023-02-21 -0.010464
# 2023-02-22 -0.014433
#
# [2467 rows x 1 columns]

# %% [markdown]
# ## SimpleExponentialSmoothing

# %%
from statsmodels.tsa.api import SimpleExpSmoothing

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
data1=data.reset_index()
data1
# Out:
#            Date         Open         High          Low        Close  \
# 0    2013-02-22   725.000000   732.025024   721.150024   727.549988
# 1    2013-02-25   726.500000   737.500000   725.750000   736.849976
# 2    2013-02-26   733.500000   749.974976   733.000000   748.200012
# 3    2013-02-27   747.625000   751.525024   738.650024   741.599976
# 4    2013-02-28   743.125000   762.500000   742.625000   758.500000
# ...         ...          ...          ...          ...          ...
# 2462 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049
# 2463 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902
# 2464 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049
# 2465 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000
# 2466 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049
#
#         Adj Close     Volume
# 0      589.708862  1310694.0
# 1      597.246765  1730030.0
# 2      606.446533  2853670.0
# 3      601.096863  2556682.0
# ...

# %%
data1=data1.drop(['Date'],axis=1)
data1
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0      725.000000   732.025024   721.150024   727.549988   589.708862
# 1      726.500000   737.500000   725.750000   736.849976   597.246765
# 2      733.500000   749.974976   733.000000   748.200012   606.446533
# 3      747.625000   751.525024   738.650024   741.599976   601.096863
# 4      743.125000   762.500000   742.625000   758.500000   614.794861
# ...           ...          ...          ...          ...          ...
# 2462  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2463  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2464  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2465  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2466  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#          Volume
# 0     1310694.0
# 1     1730030.0
# 2     2853670.0
# 3     2556682.0
# 4     4599424.0
# ...         ...
# ...

# %%
train=data1[0:1728]
test=data1[1728:]

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
ses_model = SimpleExpSmoothing(train["Close"]).fit(smoothing_level=0.2)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])

# %%
from sklearn.metrics import mean_squared_error

simplermse=print(np.sqrt(mean_squared_error(pred_ses,test.Close)))
simplermse
# Out:
# 1141.5784268220227

# %%
ses_model = SimpleExpSmoothing(train["Close"]).fit(smoothing_level=0.6)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])

# %%
simplermse=print(np.sqrt(mean_squared_error(pred_ses,test.Close)))
simplermse
# Out:
# 1159.4409014361108

# %%
ses_model = SimpleExpSmoothing(train["Close"]).fit()
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])

# %%
simplermse=print(np.sqrt(mean_squared_error(pred_ses,test.Close)))
simplermse
# Out:
# 1140.7544772849976

# %% [markdown]
# ## Holt's Winter

# %%
from statsmodels.tsa.holtwinters import Holt 

hw_model = Holt(train["Close"]).fit(smoothing_level=0.8, smoothing_trend=0.2)
pred_hw = hw_model.predict(start = test.index[0],end = test.index[-1])

# %%
holtrmse=print(np.sqrt(mean_squared_error(pred_hw,test.Close)))
holtrmse
# Out:
# 2348.995827851325

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing 

hwe_model_add_add = ExponentialSmoothing(train["Close"],seasonal="add",trend="add",seasonal_periods=12).fit()
pred_hwe_add_add = hwe_model_add_add.predict(start = test.index[0],end = test.index[-1])

# %%
hwe_add_rmse=print(np.sqrt(mean_squared_error(pred_hwe_add_add,test.Close)))
hwe_add_rmse
# Out:
# 1001.7364620880147

# %%
hwe_model_mul_add = ExponentialSmoothing(train["Close"],seasonal="mul",trend="add",seasonal_periods=12).fit() 
pred_hwe_mul_add = hwe_model_add_add.predict(start = test.index[0],end = test.index[-1])

# %%
hwe_mul_rmse=print(np.sqrt(mean_squared_error(pred_hwe_mul_add,test.Close)))
hwe_mul_rmse
# Out:
# 1001.7364620880147

# %% [markdown]
# ## ARIMA

# %%
log_data
# Out:
#                Close
# Date
# 2013-02-22       NaN
# 2013-02-25  0.012702
# 2013-02-26  0.015286
# 2013-02-27 -0.008860
# 2013-02-28  0.022533
# ...              ...
# 2023-02-16  0.010567
# 2023-02-17 -0.016121
# 2023-02-20 -0.003964
# 2023-02-21 -0.010464
# 2023-02-22 -0.014433
#
# [2467 rows x 1 columns]

# %%
log_data.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
log_data=log_data.dropna()
log_data
# Out:
#                Close
# Date
# 2013-02-25  0.012702
# 2013-02-26  0.015286
# 2013-02-27 -0.008860
# 2013-02-28  0.022533
# 2013-03-01 -0.010037
# ...              ...
# 2023-02-16  0.010567
# 2023-02-17 -0.016121
# 2023-02-20 -0.003964
# 2023-02-21 -0.010464
# 2023-02-22 -0.014433
#
# [2466 rows x 1 columns]

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
model=auto_arima(log_data,
                 m=12,seasonal=False,
                 start_p=0,start_q=0,test='adf',error_action='ignore',
                 max_p=7,max_q=7,
                 suppress_warnings=True,
                 stepwise=True,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-13528.005, Time=0.46 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-13526.400, Time=0.17 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-13526.409, Time=0.51 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-13525.687, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-13529.986, Time=0.63 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-13528.490, Time=1.21 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-13528.503, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-13529.559, Time=1.58 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 5.347 seconds

# %%
train=log_data.iloc[:-30]
test=log_data[-30:]

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(train,order=(0,1,1))
model=model.fit()
print(model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 2436
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                6668.992
# Date:                Thu, 23 Mar 2023   AIC                         -13333.985
# Time:                        10:37:04   BIC                         -13322.389
# Sample:                             0   HQIC                        -13329.770
#                                - 2436
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0000      0.089    -11.273      0.000      -1.174      -0.826
# sigma2         0.0002   2.17e-05     11.208      0.000       0.000       0.000
# ...
# Ljung-Box (L1) (Q):                   0.48   Jarque-Bera (JB):              1206.05
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,type='levels')
pred.index=log_data.index[start:end+1]
print(pred)
# Out:
# Date
# 2023-01-11    0.000528
# 2023-01-12    0.000528
# 2023-01-13    0.000528
# 2023-01-16    0.000528
# 2023-01-17    0.000528
# 2023-01-18    0.000528
# 2023-01-19    0.000528
# 2023-01-20    0.000528
# 2023-01-23    0.000528
# 2023-01-24    0.000528
# 2023-01-25    0.000528
# 2023-01-27    0.000528
# 2023-01-30    0.000528
# 2023-01-31    0.000528
# 2023-02-01    0.000528
# 2023-02-02    0.000528
# 2023-02-03    0.000528
# 2023-02-06    0.000528
# 2023-02-07    0.000528
# 2023-02-08    0.000528
# 2023-02-09    0.000528
# 2023-02-10    0.000528
# 2023-02-13    0.000528
# 2023-02-14    0.000528
# 2023-02-15    0.000528
# 2023-02-16    0.000528
# 2023-02-17    0.000528
# 2023-02-20    0.000528
# 2023-02-21    0.000528
# 2023-02-22    0.000528
# Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(pred,test))
print(rmse)
# Out:
# 0.010419021887606905

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(train['Close'],order=(1,0,1),seasonal_order=(1,0,0,12))
model=model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                               Close   No. Observations:                 2436
# Model:             SARIMAX(1, 0, 1)x(1, 0, [], 12)   Log Likelihood                6677.165
# Date:                             Thu, 23 Mar 2023   AIC                         -13346.330
# Time:                                     10:37:29   BIC                         -13323.137
# Sample:                                          0   HQIC                        -13337.899
#                                             - 2436
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7829      0.282      2.774      0.006       0.230       1.336
# ...

# %%
pred=model.predict(start=start,end=end,dynamic=True)

# %%
pred
# Out:
# 2436    2.788825e-04
# 2437    6.046257e-05
# 2438   -4.662030e-05
# 2439    1.312001e-04
# 2440   -1.596686e-04
# 2441    5.085841e-05
# 2442    6.076961e-04
# 2443    3.532502e-05
# 2444   -4.720771e-05
# 2445   -1.237490e-03
# 2446    1.340017e-03
# 2447   -4.125933e-04
# 2448    9.820789e-06
# 2449    1.304476e-06
# 2450   -2.778195e-06
# 2451    4.606417e-06
# 2452   -7.004083e-06
# 2453    1.628108e-06
# 2454    2.423876e-05
# 2455    1.165818e-06
# 2456   -2.114652e-06
# 2457   -5.020311e-05
# 2458    5.406206e-05
# 2459   -1.678330e-05
# 2460    3.198701e-07
# 2461   -7.742756e-09
# 2462   -1.597074e-07
# 2463    1.491958e-07
# 2464   -3.122648e-07
# 2465    4.310925e-08
# Name: predicted_mean, dtype: float64

# %%
pred.index=log_data.index[start:end+1]
print(pred)
# Out:
# Date
# 2023-01-11    2.788825e-04
# 2023-01-12    6.046257e-05
# 2023-01-13   -4.662030e-05
# 2023-01-16    1.312001e-04
# 2023-01-17   -1.596686e-04
# 2023-01-18    5.085841e-05
# 2023-01-19    6.076961e-04
# 2023-01-20    3.532502e-05
# 2023-01-23   -4.720771e-05
# 2023-01-24   -1.237490e-03
# 2023-01-25    1.340017e-03
# 2023-01-27   -4.125933e-04
# 2023-01-30    9.820789e-06
# 2023-01-31    1.304476e-06
# 2023-02-01   -2.778195e-06
# 2023-02-02    4.606417e-06
# 2023-02-03   -7.004083e-06
# 2023-02-06    1.628108e-06
# 2023-02-07    2.423876e-05
# 2023-02-08    1.165818e-06
# 2023-02-09   -2.114652e-06
# 2023-02-10   -5.020311e-05
# 2023-02-13    5.406206e-05
# 2023-02-14   -1.678330e-05
# 2023-02-15    3.198701e-07
# 2023-02-16   -7.742756e-09
# 2023-02-17   -1.597074e-07
# 2023-02-20    1.491958e-07
# 2023-02-21   -3.122648e-07
# 2023-02-22    4.310925e-08
# Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(pred,test['Close']))
print(rmse*100)
# Out:
# 1.0511690707706367

# %% [markdown]
# ## LSTM

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-22   725.000000   732.025024   721.150024   727.549988   589.708862
# 2013-02-25   726.500000   737.500000   725.750000   736.849976   597.246765
# 2013-02-26   733.500000   749.974976   733.000000   748.200012   606.446533
# 2013-02-27   747.625000   751.525024   738.650024   741.599976   601.096863
# 2013-02-28   743.125000   762.500000   742.625000   758.500000   614.794861
# ...                 ...          ...          ...          ...          ...
# 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049  3558.050049
# 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902  3501.149902
# 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049  3487.300049
# 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000  3451.000000
# 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049  3401.550049
#
#                Volume
# Date
# ...

# %%
data1=data.reset_index()
data1
# Out:
#            Date         Open         High          Low        Close  \
# 0    2013-02-22   725.000000   732.025024   721.150024   727.549988
# 1    2013-02-25   726.500000   737.500000   725.750000   736.849976
# 2    2013-02-26   733.500000   749.974976   733.000000   748.200012
# 3    2013-02-27   747.625000   751.525024   738.650024   741.599976
# 4    2013-02-28   743.125000   762.500000   742.625000   758.500000
# ...         ...          ...          ...          ...          ...
# 2462 2023-02-16  3527.199951  3575.000000  3527.000000  3558.050049
# 2463 2023-02-17  3526.149902  3538.899902  3490.000000  3501.149902
# 2464 2023-02-20  3502.000000  3522.000000  3475.050049  3487.300049
# 2465 2023-02-21  3494.000000  3508.899902  3444.750000  3451.000000
# 2466 2023-02-22  3414.949951  3447.000000  3395.000000  3401.550049
#
#         Adj Close     Volume
# 0      589.708862  1310694.0
# 1      597.246765  1730030.0
# 2      606.446533  2853670.0
# 3      601.096863  2556682.0
# ...

# %%
df1=data1.reset_index()['Close']

# %%
df1.shape
# Out:
# (2467,)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2467 entries, 0 to 2466
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2467 non-null   datetime64[ns]
#  1   Open       2467 non-null   float64
#  2   High       2467 non-null   float64
#  3   Low        2467 non-null   float64
#  4   Close      2467 non-null   float64
#  5   Adj Close  2467 non-null   float64
#  6   Volume     2467 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 135.0 KB

# %%
from sklearn.preprocessing import MinMaxScaler
normalizer=MinMaxScaler(feature_range=(0,1))
df1=normalizer.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1
# Out:
# array([[0.0128581 ],
#        [0.01564714],
#        [0.01905098],
#        ...,
#        [0.84049967],
#        [0.82961338],
#        [0.81478348]])

# %%
training_size=int(len(df1)*0.70)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (1726, 741)

# %%
def create_dataset(dataset,time_step=1):
    dataX,dataY=[],[]
    for i in range(len(dataset)-time_step-1):
        a=dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX),np.array(dataY)

# %%
time_step=100
x_train,y_train=create_dataset(train_data,time_step)
x_test,y_test=create_dataset(test_data,time_step)

# %%
x_train.shape,y_train.shape
# Out:
# ((1625, 100), (1625,))

# %%
x_test.shape,y_test.shape
# Out:
# ((640, 100), (640,))

# %%
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=50,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 47s 485ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 2/10
# 33/33 [==============================] - 10s 314ms/step - loss: 3.7624e-04 - val_loss: 0.0044
# Epoch 3/10
# 33/33 [==============================] - 9s 267ms/step - loss: 3.3634e-04 - val_loss: 0.0028
# Epoch 4/10
# 33/33 [==============================] - 9s 276ms/step - loss: 3.2337e-04 - val_loss: 0.0021
# Epoch 5/10
# 33/33 [==============================] - 9s 287ms/step - loss: 3.3556e-04 - val_loss: 0.0041
# Epoch 6/10
# 33/33 [==============================] - 9s 272ms/step - loss: 3.1510e-04 - val_loss: 0.0043
# Epoch 7/10
# 33/33 [==============================] - 9s 277ms/step - loss: 3.1747e-04 - val_loss: 0.0043
# Epoch 8/10
# 33/33 [==============================] - 9s 279ms/step - loss: 3.1054e-04 - val_loss: 0.0036
# Epoch 9/10
# 33/33 [==============================] - 9s 279ms/step - loss: 2.9256e-04 - val_loss: 0.0019
# Epoch 10/10
# ...

# %%
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
# Out:
# ...
# 20/20 [==============================] - 2s 94ms/step

# %%
x_train.shape
# Out:
# (1625, 100, 1)

# %%
train_predict=normalizer.inverse_transform(train_predict)
test_predict=normalizer.inverse_transform(test_predict)

# %%
np.sqrt(mean_squared_error(train_predict,y_train))
# Out:
# 1503.0673075145285

# %%
np.sqrt(mean_squared_error(test_predict,y_test))
# Out:
# 3178.8634772203036

# %%
look_back=100
trainPredictPlot=np.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict

testPredictPlot=np.empty_like(df1)
testPredictPlot[:,:]=np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict

plt.plot(normalizer.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 741

# %%
x_input=test_data[641:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        print('{} day input {}'.format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input=x_input.reshape(1,n_steps,1)
        yhat=model.predict(x_input,verbose=0)
        print('{} day output {}'.format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input=x_input.reshape(1,n_steps,1)
        yhat=model.predict(x_input,verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

print(lst_output)
# Out:
# [0.81505245]
# 101
# 1 day input [0.68984623 0.72169531 0.72493422 0.71382301 0.72991254 0.71521757
#  0.72457436 0.72533911 0.72409449 0.72787323 0.73775483 0.73090222
#  0.74153356 0.73556556 0.74285308 0.74297308 0.74156351 0.74331794
#  0.75228484 0.77224302 0.76684486 0.75636347 0.75955735 0.76444569
#  0.75915253 0.75603355 0.78911224 0.79497525 0.79410557 0.80092824
#  0.79902386 0.79735941 0.77938059 0.78881234 0.78681805 0.80836563
#  0.81121465 0.81289411 0.81352392 0.81155958 0.83700582 0.82605957
#  0.82208593 0.80992515 0.80850064 0.79948871 0.78215464 0.78026527
#  0.79395562 0.80392721 0.7858584  0.76641003 0.75495397 0.76751963
#  0.77489714 0.77224302 0.76284128 0.7702037  0.77218305 0.77146333
#  0.7749571  0.77134332 0.77276784 0.78773275 0.78872236 0.78765778
#  0.75780299 0.79031183 0.78025026 0.79293593 0.79463039 0.80668625
#  0.79454041 0.80784081 0.81131965 0.80625141 0.80325244 0.81878706
#  0.82520491 0.82324056 0.8176325  0.82441013 0.80193285 0.81682279
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(df1)-100
# Out:
# 2367

# %%
plt.plot(day_new,normalizer.inverse_transform(df1[2367:]))
plt.plot(day_pred,normalizer.inverse_transform(lst_output))

# %%
model.save('kera_model.h5')
